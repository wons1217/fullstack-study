# %%
print("Hello from Home Jupyter!"
# Out:
#   Cell In[1], line 1
#     print("Hello from Home Jupyter!"
#                                     ^
# SyntaxError: incomplete input

# %%
print(Hello from Home Jupyter!")
# Out:
#   Cell In[2], line 1
#     print(Hello from Home Jupyter!")
#                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Hello from Home Jupyter!")
# Out:
# Hello from Home Jupyter!
